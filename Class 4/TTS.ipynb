# %% [markdown]
# <a href="https://colab.research.google.com/github/Huyenle13/GS2DIT/blob/main/Class%204/TTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Let's try today to make AI model speak :)

# %% [markdown]
# Install all necessary dependencies and download the models

# %%
import os
# !git clone https://github.com/TensorSpeech/TensorFlowTTS
os.chdir("TensorFlowTTS")
# !pip install  .
os.chdir("..")
import sys
sys.path.append("TensorFlowTTS/")
# Out:
# Cloning into 'TensorFlowTTS'...
# remote: Enumerating objects: 10679, done.
# remote: Total 10679 (delta 0), reused 0 (delta 0), pack-reused 10679
# Receiving objects: 100% (10679/10679), 133.52 MiB | 10.26 MiB/s, done.
# Resolving deltas: 100% (5163/5163), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/TensorFlowTTS
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow-gpu==2.7.0
#   Downloading tensorflow_gpu-2.7.0-cp39-cp39-manylinux2010_x86_64.whl (489.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.7/489.7 MB 3.8 MB/s eta 0:00:00
# Collecting tensorflow-addons>=0.10.0
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=38.5.1 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (67.6.1)
# Collecting huggingface_hub==0.0.8
#   Downloading huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Requirement already satisfied: librosa>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (0.10.0.post2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (0.12.1)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (3.7.1)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (6.0)
# Requirement already satisfied: tqdm>=4.26.1 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (4.65.0)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (3.8.0)
# Collecting unidecode>=1.1.1
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: inflect>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (6.0.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (1.2.2)
# Collecting pyworld>=0.2.10
#   Downloading pyworld-0.3.2.tar.gz (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 KB 24.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba>=0.48 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (0.56.4)
# Collecting jamo>=0.4.1
#   Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Collecting pypinyin
#   Downloading pypinyin-0.48.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.9 MB/s eta 0:00:00
# Collecting g2pM
#   Downloading g2pM-0.1.2.5-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 23.3 MB/s eta 0:00:00
# Collecting textgrid
#   Downloading TextGrid-1.5-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (8.1.3)
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 99.5 MB/s eta 0:00:00
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting pyopenjtalk
#   Downloading pyopenjtalk-0.3.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface_hub==0.0.8->TensorFlowTTS==0.0) (3.10.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface_hub==0.0.8->TensorFlowTTS==0.0) (2.27.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (0.32.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (16.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (1.6.3)
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.3 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (2.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (1.53.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (0.40.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (1.16.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (1.4.0)
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (3.20.3)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.1/463.1 KB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (0.4.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (2.12.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (0.2.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (4.5.0)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from inflect>=4.1.0->TensorFlowTTS==0.0) (1.10.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.7.0->TensorFlowTTS==0.0) (0.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.7.0->TensorFlowTTS==0.0) (1.10.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.7.0->TensorFlowTTS==0.0) (4.4.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.7.0->TensorFlowTTS==0.0) (3.0.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.7.0->TensorFlowTTS==0.0) (0.3.4)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.7.0->TensorFlowTTS==0.0) (1.1.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.7.0->TensorFlowTTS==0.0) (1.6.0)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.7.0->TensorFlowTTS==0.0) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.1.0->TensorFlowTTS==0.0) (3.0.9)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.48->TensorFlowTTS==0.0) (0.39.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.9/dist-packages (from pyworld>=0.2.10->TensorFlowTTS==0.0) (0.29.33)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.0->TensorFlowTTS==0.0) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.9/dist-packages (from soundfile>=0.10.2->TensorFlowTTS==0.0) (1.15.1)
# Collecting typeguard>=2.7
#   Downloading typeguard-3.0.2-py3-none-any.whl (30 kB)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 KB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.9/dist-packages (from g2p_en->TensorFlowTTS==0.0) (3.8.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0->soundfile>=0.10.2->TensorFlowTTS==0.0) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.1.0->TensorFlowTTS==0.0) (3.15.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk>=3.2.4->g2p_en->TensorFlowTTS==0.0) (2022.10.31)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pooch<1.7,>=1.0->librosa>=0.7.0->TensorFlowTTS==0.0) (1.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface_hub==0.0.8->TensorFlowTTS==0.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface_hub==0.0.8->TensorFlowTTS==0.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface_hub==0.0.8->TensorFlowTTS==0.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface_hub==0.0.8->TensorFlowTTS==0.0) (2.0.12)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (2.17.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (1.8.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow-addons>=0.10.0->TensorFlowTTS==0.0) (6.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow-gpu==2.7.0->TensorFlowTTS==0.0) (3.2.2)
# Building wheels for collected packages: TensorFlowTTS, pyworld, pyopenjtalk, distance
#   Building wheel for TensorFlowTTS (setup.py) ... done
#   Created wheel for TensorFlowTTS: filename=TensorFlowTTS-0.0-py3-none-any.whl size=133231 sha256=06fa249785455f3ef37655be88affb93ac01d809cba21d605cf56cd05b12d810
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5wlb19tb/wheels/cd/09/5d/fe6c31316c44d6489846185db9ce774511a85462f0682a9747
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.2-cp39-cp39-linux_x86_64.whl size=895522 sha256=3f89d9ee2d0f79a77c8f6642487ac9ff9242c886e13d17315ec493259b81ec32
#   Stored in directory: /root/.cache/pip/wheels/c5/91/01/58aa68f1f055ce534049e668292b710500100da0262079b8f5
#   Building wheel for pyopenjtalk (pyproject.toml) ... done
#   Created wheel for pyopenjtalk: filename=pyopenjtalk-0.3.0-cp39-cp39-linux_x86_64.whl size=5843212 sha256=23e2f904b03c5f8cce13c754c2f648e3cd82b0e626caa488a1ec9b1965937986
#   Stored in directory: /root/.cache/pip/wheels/cd/be/cb/a02e2b329fbd3fd99dfaafddda7ff489cda625ec89f4dbd5a1
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16275 sha256=6aa25e696e46425dc7013c491cc919b4d90677b3652fb40eccb88d49b006314a
#   Stored in directory: /root/.cache/pip/wheels/fb/b3/aa/04241cced6d1722b132273b1d6aafba317887ec004f48b853a
# Successfully built TensorFlowTTS pyworld pyopenjtalk distance
# Installing collected packages: textgrid, tensorflow-estimator, keras, jamo, flatbuffers, distance, dataclasses, unidecode, pyworld, pypinyin, pyopenjtalk, keras-preprocessing, g2pM, typeguard, huggingface_hub, tensorflow-addons, g2p_en, tensorflow-gpu, TensorFlowTTS
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.3.3
#     Uninstalling flatbuffers-23.3.3:
#       Successfully uninstalled flatbuffers-23.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires keras<2.13,>=2.12.0, but you have keras 2.7.0 which is incompatible.
# tensorflow 2.12.0 requires tensorflow-estimator<2.13,>=2.12.0, but you have tensorflow-estimator 2.7.0 which is incompatible.
# Successfully installed TensorFlowTTS-0.0 dataclasses-0.6 distance-0.1.3 flatbuffers-2.0.7 g2pM-0.1.2.5 g2p_en-2.1.0 huggingface_hub-0.0.8 jamo-0.4.1 keras-2.7.0 keras-preprocessing-1.1.2 pyopenjtalk-0.3.0 pypinyin-0.48.0 pyworld-0.3.2 tensorflow-addons-0.19.0 tensorflow-estimator-2.7.0 tensorflow-gpu-2.7.0 textgrid-1.5 typeguard-3.0.2 unidecode-1.3.6

# %%
import numpy as np
import soundfile as sf
import yaml

import tensorflow as tf

from tensorflow_tts.inference import TFAutoModel
from tensorflow_tts.inference import AutoProcessor
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.

# %%
# initialize fastspeech2 model.
fastspeech2 = TFAutoModel.from_pretrained("tensorspeech/tts-fastspeech2-ljspeech-en")

# initialize mb_melgan model
mb_melgan = TFAutoModel.from_pretrained("tensorspeech/tts-mb_melgan-ljspeech-en")

# inference
processor = AutoProcessor.from_pretrained("tensorspeech/tts-fastspeech2-ljspeech-en")
# Out:
# Downloading:   0%|          | 0.00/125M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.71k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.83k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.57k [00:00<?, ?B/s]

# %% [markdown]
# Provide a text you would like to be said.

# %%
input_ids = processor.text_to_sequence("WHO IS THERE?")

# %% [markdown]
# Inference (ask) the model.

# %%
# fastspeech inference
mel_before, mel_after, duration_outputs, _, _ = fastspeech2.inference(
    input_ids=tf.expand_dims(tf.convert_to_tensor(input_ids, dtype=tf.int32), 0),
    speaker_ids=tf.convert_to_tensor([9], dtype=tf.int32),
    speed_ratios=tf.convert_to_tensor([1.0], dtype=tf.float32),
    f0_ratios =tf.convert_to_tensor([1.0], dtype=tf.float32),
    energy_ratios =tf.convert_to_tensor([1.0], dtype=tf.float32),
)

# melgan inference
audio_before = mb_melgan.inference(mel_before)[0, :, 0]
audio_after = mb_melgan.inference(mel_after)[0, :, 0]

# save to file
sf.write('./audio_before.wav', audio_before, 22050, "PCM_16")
sf.write('./audio_after.wav', audio_after, 22050, "PCM_16")

# %%
import IPython.display as ipd

# %% [markdown]
# Listen to the model output.

# %%
ipd.Audio(audio_before, rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
